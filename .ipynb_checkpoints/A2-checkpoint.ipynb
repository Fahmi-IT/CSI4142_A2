# %% [markdown]
# Name: Fahmi Sajid Ahmed
#
# Student Number: 300250180

# %% [markdown]
# Dataset URL: https://www.kaggle.com/datasets/likithagedipudi/starbucks-customer-ordering-patterns
#
# This is CSI4142 A2. The purpose of this portion of the assignment is to explore various imputation methods.

# %% [markdown]
# 1.1
# Type of Imputation:
# Which attribute is being impacted:

# %% [markdown]
# 1.2
# Removal Type:

# %%
# 1.3
# Code Here

# %% [markdown]
# 1.4
# Evaluation Here
